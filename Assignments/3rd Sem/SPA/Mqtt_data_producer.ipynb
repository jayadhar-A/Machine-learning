# %%
# !pip install pykafka

# %%
# !pip install paho-mqtt

# %%
import json

import paho.mqtt.client as mqtt
from pykafka import KafkaClient
from random import randrange,uniform
import random
import time

mqtt_broker = 'mqtt.eclipseprojects.io'
client = mqtt.Client("MqttProducer")
client.connect(mqtt_broker)

while True:
    data_0 = { "truck":"1","NamePlate": "TS07EQ2812", "Latitude": "17.0", "Longitude": "34.0", "route": "NH44", "Speed":"100", "Tyre_Pressure": "8.0", "Fuel Level": "29", "Driver_Name": "David" }
    data_1 = { "truck":"2","NamePlate": "KA02EF0013", "Latitude": "65.3", "Longitude": "89.43", "route": "NH11", "Speed":"75", "Tyre_Pressure": "8.5", "Fuel Level": "43", "Driver_Name": "Rakesh" }
    data_2 = { "truck":"3", "NamePlate": "TS05EZ8772", "Latitude": "62.0", "Longitude": "54.3", "route": "NH23", "Speed":"67", "Tyre_Pressure": "8.6", "Fuel Level": "34", "Driver_Name": "Manoj"}
    data_3 = { "truck":"4", "NamePlate": "AP02FQ0102", "Latitude": "76.2", "Longitude": "74.6", "route": "NH07", "Speed":"45", "Tyre_Pressure": "7.8", "Fuel Level": "56", "Driver_Name": "Alex" }
    data_4 = { "truck":"5", "NamePlate": "AP39TZ9822", "Latitude": "45.3", "Longitude": "65.3", "route": "NH44", "Speed":"56", "Tyre_Pressure": "9.2", "Fuel Level": "45", "Driver_Name" : "Jessie" }
    client.publish("data", json.dumps(data_0))
    print("just Published ", json.dumps(data_0))
    client.publish("data", json.dumps(data_1))
    print("just Published ", json.dumps(data_1))
    client.publish("data", json.dumps(data_2))
    print("just Published ", json.dumps(data_2))
    client.publish("data", json.dumps(data_3))
    print("just Published ", json.dumps(data_3))
    client.publish("data", json.dumps(data_4))
    print("just Published ", json.dumps(data_4))
    time.sleep(3)
# Out:
# just Published  {"truck": "1", "NamePlate": "TS07EQ2812", "Latitude": "17.0", "Longitude": "34.0", "route": "NH44", "Speed": "100", "Tyre_Pressure": "8.0", "Fuel Level": "29", "Driver_Name": "David"}
# just Published  {"truck": "2", "NamePlate": "KA02EF0013", "Latitude": "65.3", "Longitude": "89.43", "route": "NH11", "Speed": "75", "Tyre_Pressure": "8.5", "Fuel Level": "43", "Driver_Name": "Rakesh"}
# just Published  {"truck": "3", "NamePlate": "TS05EZ8772", "Latitude": "62.0", "Longitude": "54.3", "route": "NH23", "Speed": "67", "Tyre_Pressure": "8.6", "Fuel Level": "34", "Driver_Name": "Manoj"}
# just Published  {"truck": "4", "NamePlate": "AP02FQ0102", "Latitude": "76.2", "Longitude": "74.6", "route": "NH07", "Speed": "45", "Tyre_Pressure": "7.8", "Fuel Level": "56", "Driver_Name": "Alex"}
# ...
