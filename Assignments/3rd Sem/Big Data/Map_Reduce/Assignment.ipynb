# %%
# import required libraries
import numpy as np
import pandas as pd
import os

# %%
path = os.path.abspath(os.getcwd())

# %%
path
# Out:
# 'C:\\Users\\jayad\\BigData'

# %%
# Preprocessing
geosales_df = pd.read_csv(os.path.join(os.path.abspath(os.getcwd()),"geosales.csv"));

# %%
geosales_df.head()
# Out:
#    index                 region         country      item_type sales_channel  \
# 0  13465  Australia and Oceania           Tonga         Snacks        Online
# 1  84289                 Europe  Czech Republic      Baby Food        Online
# 2   6703                 Europe         Ukraine      Baby Food       Offline
# 3  81234                 Europe         Romania  Personal Care        Online
# 4  75679     Sub-Saharan Africa        Tanzania  Personal Care       Offline
#
#   order_priority           order_date   order_id            ship_date  \
# 0              C  2017-05-04 00:00:00  659991061  2017-05-27 00:00:00
# 1              L  2015-06-01 00:00:00  140080249  2015-06-11 00:00:00
# 2              L  2018-08-17 00:00:00  614736831  2018-08-28 00:00:00
# 3              C  2018-04-10 00:00:00  543800771  2018-05-11 00:00:00
# 4              L  2020-03-24 00:00:00  402419173  2020-04-30 00:00:00
#
#    units_sold  unit_price  unit_cost  total_revenue  total_cost  total_profit
# ...

# %%
geosales_df.groupby(['region','country','item_type','order_date']).agg({'unit_price': ['mean']})
# Out:
#                                                              unit_price
#                                                                    mean
# region             country    item_type  order_date
# Asia               Bangladesh Baby Food  2014-02-17 00:00:00     255.28
#                                          2014-04-09 00:00:00     255.28
#                                          2014-04-20 00:00:00     255.28
#                                          2014-06-01 00:00:00     255.28
#                                          2014-11-28 00:00:00     255.28
# ...                                                                 ...
# Sub-Saharan Africa Zimbabwe   Vegetables 2019-10-17 00:00:00     154.06
#                                          2019-10-18 00:00:00     154.06
#                                          2020-01-29 00:00:00     154.06
#                                          2020-03-07 00:00:00     154.06
# ...

# %%
geosales_df1=pd.DatetimeIndex(geosales_df['order_date']).year

# %%
geosales_df2=geosales_df
geosales_df2.insert (7, "order_year", df1)

# %%
geosales_df2.to_csv(os.path.join(os.path.abspath(os.getcwd()),'geosales_modified.csv'),header=None,index=False)
